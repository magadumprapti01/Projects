# %%
from google.colab import files

uploaded=files.upload()
# Out:
#      <input type="file" id="files-8dbfb58f-b122-44fd-93a7-f40b44fa5007" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8dbfb58f-b122-44fd-93a7-f40b44fa5007">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('student-por.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.size
# Out:
# 21417

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns=df.columns.str.strip().str.lower()

# %%
df.head()
# Out:
#   school sex  age address famsize pstatus  medu  fedu     mjob      fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  dalc  walc health absences  g1  g2  g3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df['g3']
# Out:
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: g3, Length: 649, dtype: int64

# %%
df['g2']
# Out:
# 0      11
# 1      11
# 2      13
# 3      14
# 4      13
#        ..
# 644    11
# 645    15
# 646    12
# 647    10
# 648    11
# Name: g2, Length: 649, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# age           16.744222
# medu           2.514638
# fedu           2.306626
# traveltime     1.568567
# studytime      1.930663
# failures       0.221880
# famrel         3.930663
# freetime       3.180277
# goout          3.184900
# dalc           1.502311
# walc           2.280431
# health         3.536210
# absences       3.659476
# g1            11.399076
# g2            11.570108
# g3            11.906009
# dtype: float64

# %%
df['g2'].mean()
# Out:
# np.float64(11.570107858243452)

# %%
df['g3'].max()
# Out:
# 19

# %%
df['g3'].min()
# Out:
# 0

# %%
df['g2'].max()
# Out:
# 19

# %%
df['g2'].min()
# Out:
# 0

# %%
#what if i need the full detail of the best student

best_student=df.loc[df['g3'].idxmax()]
df['g3'].idxmax()
best_student
# Out:
# school                GP
# sex                    F
# age                   17
# address                R
# famsize              LE3
# pstatus                T
# medu                   3
# fedu                   1
# mjob            services
# fjob               other
# reason        reputation
# guardian          mother
# traveltime             2
# studytime              4
# failures               0
# schoolsup             no
# famsup               yes
# paid                  no
# activities            no
# nursery              yes
# higher               yes
# internet              no
# romantic              no
# famrel                 3
# freetime               1
# goout                  2
# dalc                   1
# walc                   1
# health                 3
# absences               0
# g1                    18
# g2                    19
# g3                    19
# Name: 338, dtype: object

# %%
worst_student=df.loc[df['g3'].idxmin()]
df['g3'].idxmin()
worst_student
# Out:
# school            GP
# sex                M
# age               18
# address            U
# famsize          LE3
# pstatus            T
# medu               1
# fedu               1
# mjob           other
# fjob           other
# reason        course
# guardian      mother
# traveltime         1
# studytime          1
# failures           2
# schoolsup         no
# famsup            no
# paid              no
# activities        no
# nursery          yes
# higher            no
# internet         yes
# romantic         yes
# famrel             2
# freetime           3
# goout              5
# dalc               2
# walc               5
# health             4
# absences           0
# g1                11
# g2                 9
# g3                 0
# Name: 163, dtype: object

# %%
#find above average

avg_score=df['g3'].mean()
avg_score
# Out:
# np.float64(11.906009244992296)

# %%
above_avg_student=df[df['g3']>avg_score]
above_avg_student[['g3']]
# Out:
#      g3
# 2    12
# 3    14
# 4    13
# 5    13
# 6    13
# ..   ..
# 634  16
# 636  19
# 638  16
# 641  15
# 645  16
#
# [348 rows x 1 columns]

# %%
worst_student=df.loc[df['g2'].idxmin()]
df['g2'].idxmin()
worst_student
# Out:
# school              MS
# sex                  M
# age                 16
# address              U
# famsize            GT3
# pstatus              T
# medu                 1
# fedu                 1
# mjob           at_home
# fjob          services
# reason            home
# guardian        mother
# traveltime           2
# studytime            2
# failures             0
# schoolsup           no
# famsup             yes
# paid                no
# activities         yes
# nursery            yes
# higher             yes
# internet            no
# romantic           yes
# famrel               5
# freetime             4
# goout                5
# dalc                 4
# walc                 5
# health               3
# absences             0
# g1                   7
# g2                   0
# g3                   0
# Name: 440, dtype: object

# %%
worst_student=df.loc[df['g3'].idxmax()]
df['g3'].idxmax()
worst_student
# Out:
# school                GP
# sex                    F
# age                   17
# address                R
# famsize              LE3
# pstatus                T
# medu                   3
# fedu                   1
# mjob            services
# fjob               other
# reason        reputation
# guardian          mother
# traveltime             2
# studytime              4
# failures               0
# schoolsup             no
# famsup               yes
# paid                  no
# activities            no
# nursery              yes
# higher               yes
# internet              no
# romantic              no
# famrel                 3
# freetime               1
# goout                  2
# dalc                   1
# walc                   1
# health                 3
# absences               0
# g1                    18
# g2                    19
# g3                    19
# Name: 338, dtype: object

# %%
worst_student=df.loc[df['g1'].idxmin()]
df['g1'].idxmin()
worst_student
# Out:
# school             GP
# sex                 F
# age                18
# address             U
# famsize           GT3
# pstatus             A
# medu                4
# fedu                4
# mjob          at_home
# fjob          teacher
# reason         course
# guardian       mother
# traveltime          2
# studytime           2
# failures            0
# schoolsup         yes
# famsup             no
# paid               no
# activities         no
# nursery           yes
# higher            yes
# internet           no
# romantic           no
# famrel              4
# freetime            3
# goout               4
# dalc                1
# walc                1
# health              3
# absences            4
# g1                  0
# g2                 11
# g3                 11
# Name: 0, dtype: object

# %%
#find the top 5 students

df.sort_values(by='g3',ascending=False).head(5)[['g1','g2','g3']]
# Out:
#      g1  g2  g3
# 636  17  18  19
# 338  18  19  19
# 596  17  18  18
# 113  18  17  18
# 617  19  17  18

# %%
df.sort_values(by='g3',ascending=True).head(5)[['g1','g2','g3']]
# Out:
#      g1  g2  g3
# 603   5   0   0
# 605   5   0   0
# 597   9   0   0
# 610   8   0   0
# 626   7   5   0

# %%
df[['g1','g2','g3']].mean()
# Out:
# g1    11.399076
# g2    11.570108
# g3    11.906009
# dtype: float64

# %%
passed=(df['g3']>=10).sum()
print('passed:',passed)
# Out:
# passed: 549

# %%
df[df['absences']==0]
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 637     MS   M   18       R     GT3       T     2     1     other     other
# 639     MS   M   19       R     GT3       T     1     1     other  services
# 640     MS   M   18       R     GT3       T     4     2     other     other
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
#
# ...

# %%
df[df['absences']==0]['absences'].count()
# Out:
# np.int64(244)

# %%
df[df['g3']>df['g1']][['g1','g2']]
# Out:
#      g1  g2
# 0     0  11
# 1     9  11
# 4    11  13
# 5    12  12
# 7    10  13
# ..   ..  ..
# 641  14  17
# 642   6   9
# 643   7   9
# 645  15  15
# 648  10  11
#
# [344 rows x 2 columns]

# %%
df[(df['g1']==df['g2']) & (df['g2']==df['g3'])][['g1','g2','g3']]
# Out:
#      g1  g2  g3
# 3    14  14  14
# 10   14  14  14
# 15   17  17  17
# 19   12  12  12
# 23   10  10  10
# ..   ..  ..  ..
# 614  12  12  12
# 621  13  13  13
# 625  10  10  10
# 634  16  16  16
# 647  10  10  10
#
# [89 rows x 3 columns]

# %%
#correlation matrix code

numeric_df=df.select_dtypes(include='number')
correlation_matrix=numeric_df.corr()
print(correlation_matrix)
# Out:
#                  age      medu      fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(df['g3'],bins=10,color='pink',edgecolor='black')
plt.xlabel('Final Grade')
plt.ylabel('Frequency')
plt.title('Distribution of Final Grades')
plt.show()

# %%
#barchart
# avg final mark score by boys and girls

avg_score_by_gender=df.groupby('sex')['g3'].mean()
avg_score_by_gender
# Out:
# sex
# F    12.253264
# M    11.406015
# Name: g3, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
avg_score_by_gender.plot(kind='bar',color=['skyblue','pink'])
plt.xlabel('Gender')
plt.ylabel('Average Final Grade')
plt.title('Average Final Grade by Gender')
# Out:
# Text(0.5, 1.0, 'Average Final Grade by Gender')

# %%
#scatterplot
#study time vs g3

plt.figure(figsize=(5,4))
plt.scatter(df['studytime'],df['g3'],color='green',marker='o')
plt.xlabel('Study Time')
plt.ylabel('Final Grade')
plt.title('Study Time vs Final Grade')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
#box plot

plt.figure(figsize=(5,4))
plt.boxplot(df['g3'])
plt.ylabel('Final Grade')
plt.title('Box Plot of Final Grade')
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(df['g2'])
plt.ylabel('Final Grade')
plt.title('Box Plot of Final Grade')
plt.show()

# %%
#line plots

#avg matks for g1,g2,g3

avg_marks=df[['g1','g2','g3']].mean()
print(avg_marks)
plt.figure(figsize=(4,4))
plt.plot(avg_marks.index,avg_marks.values,marker='o',linestyle='-')
plt.xlabel('Subject')
plt.ylabel('Average Marks')
plt.title('Average Marks for Each Subject')
plt.show()
# Out:
# g1    11.399076
# g2    11.570108
# g3    11.906009
# dtype: float64

# %%
#with bar chart we will find the no of students who failed
#and passed the final grades

passed=(df['g3']>=10).sum()
failed=(df['g3']<10).sum()
print('passed:',passed)
print('failed:',failed)

plt.figure(figsize=(5,4))
plt.bar(['passed','failed'],[passed.sum(),len(df)-passed.sum()],color=['skyblue','pink'])
plt.xlabel('Result')
plt.ylabel('Number of Students')
plt.title('Number of Students who Passed and Failed')
plt.show()
# Out:
# passed: 549
# failed: 100

# %%
#histogram-absences distribution

plt.figure(figsize=(5,4))
plt.hist(df['absences'],bins=10,color='skyblue',edgecolor='black')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.title('Distribution of Absences')
plt.show()

# %%
#seaborn

#which built on top of matplotlib and its easier
#use and easier

import seaborn as sns
sns.histplot(df['g3'],bins=10)
# Out:
# <Axes: xlabel='g3', ylabel='Count'>

# %%
#scatterplot with seaborn

sns.scatterplot(x='studytime',y='g3',data=df)
# Out:
# <Axes: xlabel='studytime', ylabel='g3'>

# %%
#correlation between two specific columns

df['studytime'].corr(df['g3'])
# Out:
# np.float64(0.24978868999886314)

# %%
plt.figure(figsize=(5,4))
plt.imshow(correlation_matrix)
plt.title('Correlation Matrix')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)),correlation_matrix.columns,rotation=90)
plt.yticks(range(len(correlation_matrix.columns)),correlation_matrix.columns)
plt.show()

# %%
df=df.drop(['school','fjob'],axis=1, errors='ignore')

# %%
df=df.drop(['guardian','goout','nursery','romantic',],axis=1, errors='ignore')

# %%
df['address']=df['address'].map({'U':0,'R':1})

# %%
df['address'].unique()
# Out:
# array([0, 1])

# %%
df.shape
# Out:
# (649, 27)

# %%
df['sex']=df['sex'].map({'F':0,'M':1})

# %%
df['sex'].unique()
# Out:
# array([0, 1])

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    sex  age  address  medu  fedu  traveltime  studytime  failures  famrel  \
# 0    0   18        0     4     4           2          2         0       4
# 1    0   17        0     1     1           1          2         0       5
# 2    0   15        0     1     1           1          2         0       4
# 3    0   15        0     4     2           1          3         0       3
# 4    0   16        0     3     3           1          2         0       4
#
#    freetime  ...  mjob_teacher  reason_home  reason_other  reason_reputation  \
# 0         3  ...         False        False         False              False
# 1         3  ...         False        False         False              False
# 2         3  ...         False        False          True              False
# 3         2  ...         False         True         False              False
# 4         3  ...         False         True         False              False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                649 non-null    int64
#  1   age                649 non-null    int64
#  2   address            649 non-null    int64
#  3   medu               649 non-null    int64
#  4   fedu               649 non-null    int64
#  5   traveltime         649 non-null    int64
#  6   studytime          649 non-null    int64
#  7   failures           649 non-null    int64
#  8   famrel             649 non-null    int64
#  9   freetime           649 non-null    int64
#  10  dalc               649 non-null    int64
#  11  walc               649 non-null    int64
#  12  health             649 non-null    int64
#  13  absences           649 non-null    int64
#  14  g1                 649 non-null    int64
#  15  g2                 649 non-null    int64
# ...

# %%
# feature and target separation

x=df.drop(columns=['g3'],axis=1)
y=df['g3']

# %%
x.columns
# Out:
# Index(['sex', 'age', 'address', 'medu', 'fedu', 'traveltime', 'studytime',
#        'failures', 'famrel', 'freetime', 'dalc', 'walc', 'health', 'absences',
#        'g1', 'g2', 'famsize_LE3', 'pstatus_T', 'mjob_health', 'mjob_other',
#        'mjob_services', 'mjob_teacher', 'reason_home', 'reason_other',
#        'reason_reputation', 'schoolsup_yes', 'famsup_yes', 'paid_yes',
#        'activities_yes', 'higher_yes', 'internet_yes'],
#       dtype='object')

# %%
y.name
# Out:
# 'g3'

# %%
# train test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predictions


y_pred_train=lr.predict(x_train)
y_pred_test=lr.predict(x_test)

# %%
# MAE

from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_train,y_pred_train)
print('Mean Absolute Error:',mae)
mae=mean_absolute_error(y_test,y_pred_test)
print('Mean Absolute Error:',mae)
# Out:
# Mean Absolute Error: 0.8028401886837407
# Mean Absolute Error: 0.7293405449776199

# %%
# R2
from sklearn.metrics import r2_score
r2=r2_score(y_train,y_pred_train)
print('R2 Score:',r2)
r2=r2_score(y_test,y_pred_test)
print('R2 Score:',r2)
# Out:
# R2 Score: 0.8548589750444837
# R2 Score: 0.8549203650547563

# %%
# MSE

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_train,y_pred_train)
print('Mean Squared Error:',mse)
mse=mean_squared_error(y_test,y_pred_test)
print('Mean Squared Error:',mse)
# Out:
# Mean Squared Error: 1.5277394027402882
# Mean Squared Error: 1.4147753939358538

# %%
lr.coef_
# Out:
# array([-0.04561516,  0.04177466, -0.17988399, -0.13801114,  0.01655045,
#         0.10085664,  0.07408738, -0.1910581 , -0.05147927, -0.08865644,
#        -0.07333536,  0.01420671, -0.04445519,  0.02098717,  0.18503663,
#         0.86221345,  0.06060312, -0.07075107,  0.31800604, -0.13879109,
#         0.19397786,  0.24552763, -0.11100616, -0.52902115, -0.14177077,
#        -0.07153054,  0.14635914, -0.17719939, -0.03788937,  0.01534076,
#         0.15287149])

# %%
lr.intercept_
# Out:
# np.float64(-0.15093891707946838)
